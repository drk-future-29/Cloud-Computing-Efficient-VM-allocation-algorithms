# %% [markdown]
# # Resource Allocation

# %% [markdown]
# ## generating random number

# %%
import random
import pandas as pd
import numpy as np
file = {'hh10000_16.xlsx':[10000,16,10,1000,100,3000],'hh10000_32.xlsx':[10000,32,10,1000,100,3000],'hh10000_64.xlsx':[10000,64,10,1000,100,3000],'hh10000_128.xlsx':[10000,128,10,1000,100,3000],'hh20000_16.xlsx':[20000,16,10,1000,100,3000],'hh20000_32.xlsx':[20000,32,10,1000,100,3000],'hh20000_64.xlsx':[20000,64,10,1000,100,3000],'hh20000_128.xlsx':[20000,128,10,1000,100,3000],'hh30000_16.xlsx':[30000,16,10,1000,100,3000],'hh30000_32.xlsx':[30000,32,10,1000,100,3000],'hh30000_64.xlsx':[30000,64,10,1000,100,3000],'hh30000_128.xlsx':[30000,128,10,1000,100,3000],'hh40000_16.xlsx':[40000,16,10,1000,100,3000],'hh40000_32.xlsx':[40000,32,10,1000,100,3000],'hh40000_64.xlsx':[40000,64,10,1000,100,3000],'hh40000_128.xlsx':[40000,128,10,1000,100,3000],'hh50000_16.xlsx':[50000,16,10,1000,100,3000],'hh50000_32.xlsx':[50000,32,10,1000,100,3000],'hh50000_64.xlsx':[50000,64,10,1000,100,3000],'hh50000_128.xlsx':[50000,128,10,1000,100,3000],
        'hl10000_16.xlsx':[10000,16,1,10,100,3000],'hl10000_32.xlsx':[10000,32,1,10,100,3000],'hl10000_64.xlsx':[10000,64,1,10,100,3000],'hl10000_128.xlsx':[10000,128,1,10,100,3000],'hl20000_16.xlsx':[20000,16,1,10,100,3000],'hl20000_32.xlsx':[20000,32,1,10,100,3000],'hl20000_64.xlsx':[20000,64,1,10,100,3000],'hl20000_128.xlsx':[20000,128,1,10,100,3000],'hl30000_16.xlsx':[30000,16,1,10,100,3000],'hl30000_32.xlsx':[30000,32,1,10,100,3000],'hl30000_64.xlsx':[30000,64,1,10,100,3000],'hl30000_128.xlsx':[30000,128,1,10,100,3000],'hl40000_16.xlsx':[40000,16,1,10,100,3000],'hl40000_32.xlsx':[40000,32,1,10,100,3000],'hl40000_64.xlsx':[40000,64,1,10,100,3000],'hl40000_128.xlsx':[40000,128,1,10,100,3000],'hl50000_16.xlsx':[50000,16,1,10,100,3000],'hl50000_32.xlsx':[50000,32,1,10,100,3000],'hl50000_64.xlsx':[50000,64,1,10,100,3000],'hl50000_128.xlsx':[50000,128,1,10,100,3000],
       'lh10000_16.xlsx':[10000,16,10,1000,1,100],'lh10000_32.xlsx':[10000,32,10,1000,1,100],'lh10000_64.xlsx':[10000,64,10,1000,1,100],'lh10000_128.xlsx':[10000,128,10,1000,1,100],'lh20000_16.xlsx':[20000,16,10,1000,1,100],'lh20000_32.xlsx':[20000,32,10,1000,1,100],'lh20000_64.xlsx':[20000,64,10,1000,1,100],'lh20000_128.xlsx':[20000,128,10,1000,1,100],'lh30000_16.xlsx':[30000,16,10,1000,1,100],'lh30000_32.xlsx':[30000,32,10,1000,1,100],'lh30000_64.xlsx':[30000,64,10,1000,1,100],'lh30000_128.xlsx':[30000,128,10,1000,1,100],'lh40000_16.xlsx':[40000,16,10,1000,1,100],'lh40000_32.xlsx':[40000,32,10,1000,1,100],'lh40000_64.xlsx':[40000,64,10,1000,1,100],'lh40000_128.xlsx':[40000,128,10,1000,1,100],'lh50000_16.xlsx':[50000,16,10,1000,1,100],'lh50000_32.xlsx':[50000,32,10,1000,1,100],'lh50000_64.xlsx':[50000,64,10,1000,1,100],'lh50000_128.xlsx':[50000,128,10,1000,1,100],
       'll10000_16.xlsx':[10000,16,1,10,1,100],'ll10000_32.xlsx':[10000,32,1,10,1,100],'ll10000_64.xlsx':[10000,64,1,10,1,100],'ll10000_128.xlsx':[10000,128,1,10,1,100],'ll20000_16.xlsx':[20000,16,1,10,1,100],'ll20000_32.xlsx':[20000,32,1,10,1,100],'ll20000_64.xlsx':[20000,64,1,10,1,100],'ll20000_128.xlsx':[20000,128,1,10,1,100],'ll30000_16.xlsx':[30000,16,1,10,1,100],'ll30000_32.xlsx':[30000,32,1,10,1,100],'ll30000_64.xlsx':[30000,64,1,10,1,100],'ll30000_128.xlsx':[30000,128,1,10,1,100],'ll40000_16.xlsx':[40000,16,1,10,1,100],'ll40000_32.xlsx':[40000,32,1,10,1,100],'ll40000_64.xlsx':[40000,64,1,10,1,100],'ll40000_128.xlsx':[40000,128,1,10,1,100],'ll50000_16.xlsx':[50000,16,1,10,1,100],'ll50000_32.xlsx':[50000,32,1,10,1,100],'ll50000_64.xlsx':[50000,64,1,10,1,100],'ll50000_128.xlsx':[50000,128,1,10,1,100]}

# %%
def find_keyy(min_ct):
    for key,value in mct.items():
        if min_ct == value:
            return key

# %%
def find_task(val):
    for keys,values in task_tracker:
        if val == values:
            return keys

# %%
for yu,pa in file.items():
    makespanBeforeLoadBalancing = []
    averageResourceUtilisationBeforeLoadBal = []
    makespanAfterLoadBalancing = []
    averageResourceUtilisationAfterLoadBal = []
    for i in range(10):
        # Taking number of task and resource as an input from user
        number_of_task = pa[0]
        number_of_resource =pa[1]

        # Taking Resource speed from user
        resource_speed = {} # A dict for storing speed of respective resource like R1,R2,..,Rn
        for i in range(1,number_of_resource+1):
            a = 'R' + str(i)
            resource_speed[a] = random.randint(pa[2],pa[3])

        # Taking Task size from user
        task_size = {} # A dict for storing size of respective task like T1,T2,..,Tn
        for i in range(1,number_of_task+1):
            a = 'T' + str(i)
            task_size[a] = random.randint(pa[4],pa[5])


        mct = {} # It is a temperarory dict which is used to find which total resource speed.
        makespan_cal = {} # for calculating makespan in the end or total load on all resource.
        compute_matrix = {}
        resource_allocation = {} # task resource mapping..
        for resource in resource_speed.keys():
            mct[resource] = 0
            makespan_cal[resource] = 0


        # Resource allocation begins...

        for task,size in task_size.items(): #looping for each task_size
            b=[]
            for resource,speed in resource_speed.items(): #for every task Tn we are looping through every Resource Rn.
                compute_matrix[resource] = size/speed  # this is for storing Compute timing for each task.
            # We have come out of Resource loop....
            ct = list(compute_matrix.values())
            i=0
            for resource in mct.keys(): #If bugs come change here.(we can use dict here)
                mct[resource] = mct[resource] + ct[i]
                i=i+1
            # mct loop ends here...
            b = list(mct.values())
            min_ct = min(b) #storing minimum from mct.
            # print(min)_ct
            temp = find_key(min_ct) # can have [] this here.
            for resource in makespan_cal.keys():
                if resource == temp:
                    makespan_cal[resource] = min_ct
            resource_allocation[task] = temp

            # reversing mct from here..
            i=0
            for resource in mct.keys(): #If bugs come change here.(we can use dict here)
                if resource != temp:
                    mct[resource] = mct[resource] - ct[i]
                i=i+1

        makespan = max(makespan_cal.values()) # MAKESPAN
        makespanBeforeLoadBalancing.append(makespan)

        average_resource_utilisation = sum(makespan_cal.values()) / (number_of_resource * makespan)
        averageResourceUtilisationBeforeLoadBal.append(average_resource_utilisation * 100)

        # LOAD BALANCING

        LOR = list(makespan_cal.values())
        while(len(LOR) > 1):
            max_load = max(LOR) # maximum load 
            min_load = min(LOR) # minimum load
            LOR.remove(max_load)
            LOR.remove(min_load)

            for resource,load in makespan_cal.items():
                if load == max_load:
                    max_resource = resource # resource having maximum load
                if load == min_load:
                    min_resource = resource # resource having minimum load

            max_resource_task_list = []
            for task,resource in resource_allocation.items():
                if resource == max_resource:
                    max_resource_task_list.append(task)

            task_tracker = {}
            for resource,speed in resource_speed.items():
                if resource == max_resource:
                    max_resource_speed = speed
            for task,size in task_size.items():
                if task in max_resource_task_list:
                    task_tracker[task] = size/max_resource_speed

            average_load = sum(task_tracker.values())/len(task_tracker.values())
            list_of_max_ct = []
            for values in task_tracker.values():
                if values<=average_load:
                    list_of_max_ct.append(values)
            list_of_max_ct.sort(reverse = True)
            for i in range(len(list_of_max_ct)):
                min_load = min_load+list_of_max_ct[i]
                max_load = max_load-list_of_max_ct[i]
                # print(min_load,max_load)
                if min_load<=max_load:
                    for keys in makespan_cal.keys():
                        if keys == min_resource:
                            makespan_cal[keys] = min_load
                        if keys == max_resource:
                            makespan_cal[keys] = max_load
                    t = find_key(i)
                    for task,resource in resource_allocation.items():
                        if task == t:
                            del resource_allocation[t]
                            resource_allocation[task] = min_resource

        makespan1= max(makespan_cal.values()) # MAKESPAN
        makespanAfterLoadBalancing.append(makespan1)

        average_resource_utilisation1 = sum(makespan_cal.values()) / (number_of_resource * makespan1)
        averageResourceUtilisationAfterLoadBal.append(average_resource_utilisation1 * 100)
        
    data = {'MakesPan Before Load Balancing':makespanBeforeLoadBalancing,
       'MakesPan After Load Balancing':makespanAfterLoadBalancing,
       'AverageResourceUtilisation Before Load Balancing':averageResourceUtilisationBeforeLoadBal,
       'AverageResourceUtilisation After Load Balancing':averageResourceUtilisationAfterLoadBal}
    df = pd.DataFrame(data)
    filename = yu
    df.to_excel(filename)
